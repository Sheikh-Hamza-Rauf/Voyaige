# %%
import numpy as np
from transformers import GPT2Tokenizer, GPT2LMHeadModel, AdamW

from torch.utils.data import Dataset, DataLoader, ConcatDataset
import pandas as pd
import re
import torch
from sklearn.metrics.pairwise import cosine_similarity
import os
from nltk.corpus import wordnet as wn
import nltk
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts



# Load data from files and handle missing data
def load_data(file_path, file_type='csv'):
    if not os.path.exists(file_path):
        print(f"Error: {file_path} not found.")
        return None
    try:
        if file_type == 'csv':
            return pd.read_csv(file_path)
        elif file_type == 'json':
            return pd.read_json(file_path)
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None

# Load all required datasets
hotel_df = load_data('new_hotel_data.csv')
ratings_df = load_data('clean_hotel_review_data.json', 'json')
restaurant_df = load_data('new_restaurant_db.restaurants_data.json', 'json')
attraction_df = load_data('attraction.csv')
if hotel_df is None or ratings_df is None or restaurant_df is None or attraction_df is None:
    print("Error: One or more required datasets are missing or improperly loaded. Please check your data files.")
    exit()

# Merge hotel ratings with hotel data on 'hotel_id'
merged_df = hotel_df.merge(ratings_df, on='hotel_id', how='left')
average_ratings = merged_df.groupby('hotel_id')['rating'].mean().reset_index()
average_ratings.columns = ['hotel_id', 'average_rating']
hotel_df = hotel_df.merge(average_ratings, on='hotel_id', how='left')
hotel_df.rename(columns={'average_rating': 'Rating'}, inplace=True)

restaurant_ratings_df = load_data('new_restaurant_db.restaurants_reviews.json', 'json')
restaurant_merged_df = restaurant_df.merge(restaurant_ratings_df, on='restaurant_id', how='left')
average_restaurant_ratings = restaurant_merged_df.groupby('restaurant_id')['rating'].mean().reset_index()
average_restaurant_ratings.columns = ['restaurant_id', 'average_restaurant_ratings']
restaurant_df = restaurant_df.merge(average_restaurant_ratings, on='restaurant_id', how='left')
restaurant_df.rename(columns={'average_restaurant_ratings': 'Rating'}, inplace=True)
restaurant_df['Rating'] = restaurant_df['Rating'].fillna(3.5)

# List of facilities
facilities_list = ['Cable TV', 'Entire apartment', 'Oven stove', 'Car Rental Service', 'Ironing board', 
                   'bathroom', 'Washing machine', 'Cot', 'Entire bungalow', 'Conference Room', 
                   'Fitness Center', 'Outdoor grill', 'Fitness centre', 'Pet-friendly', 'Entire house',
                   'Pet Friendly', 'Airport shuttle', 'Terrace', 'Room Service', 'BBQ Facilities', 
                   '24-Hour Front Desk', 'Child-friendly', 'Kitchen', 'Microwave', 'Free parking', 
                   'Breakfast Buffet', 'Swimming Pool', 'Paid parking', 'Entire villa', 'Air conditioning', 
                   'Balcony', 'Spa', 'Business Center', 'Free breakfast', 'Currency Exchange', 
                   'Outdoor pool', 'Air Conditioning', 'Laundry', 'Golf Course', 'cafe', 'Indoor pool', 
                   'Parking', 'Garden', 'Patio', 'Fireplace', 'Restaurant', 'Smoking Rooms', 
                   'Babysitting Service', 'Heating', 'Paid Wi-Fi', 'Wheelchair accessible', 'Entire chalet', 
                   'Lift', 'Smoke-free', 'Entire cottage', 'Library', 'Hot tub', 'Beach access', 
                   'Family Rooms', 'Free Wi-Fi']


def preprocess_hotel_data(row):
    description = f"{row['name']} and its address is {row['address']} in {row['city']}, costing Rs{row['price']} per night. Small description: {row['about']}."
    available_facilities = [facility for facility in facilities_list if row.get(facility, 0) == 1]
    if available_facilities:
        description += " Available facilities: " + ", ".join(available_facilities) + "."
    else:
        description += " No special facilities are listed."
    return description.strip()

hotel_df['description'] = hotel_df.apply(preprocess_hotel_data, axis=1)

def preprocess_restaurant_data(row):
    return f"{row['name']} located at {row['address']} and its phone number is {row['phone_number']} in {row['city']}. The provided services are {row['service']} and opening hour is {row['Open_hour']}."

def preprocess_attraction_data(row):
    return f"{row['Name']} is a popular attraction located in {row['city']}. Its address is {row['Address']}, its category is {row['Category']}, its rating is {row['Rating']}, and its availability time is {row['Availability']}. Description: {row['Description']}."

restaurant_df['description'] = restaurant_df.apply(preprocess_restaurant_data, axis=1)
attraction_df['description'] = attraction_df.apply(preprocess_attraction_data, axis=1)





# Load the GPT-2 tokenizer and model
gpt_tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
gpt_model = GPT2LMHeadModel.from_pretrained('gpt2')

# Set the padding token for the GPT-2 tokenizer
gpt_tokenizer.pad_token = gpt_tokenizer.eos_token  # Set padding token to EOS token

class GPT2BERTDataset(Dataset):
    def __init__(self, descriptions, embeddings, tokenizer):
        self.descriptions = descriptions
        self.embeddings = embeddings
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.descriptions)

    def __getitem__(self, idx):
        # Convert text description to tokens
        description = self.descriptions[idx]
        embedding = self.embeddings[idx]
        
        # Tokenize description with padding
        tokenized_input = self.tokenizer.encode(description, return_tensors='pt', padding='max_length', max_length=100, truncation=True).squeeze(0)
        
        return tokenized_input, torch.tensor(embedding, dtype=torch.float32)

# Load embeddings from the specified files
hotel_embedding_matrix = np.load('hotel_embeddings.npy')  # Load hotel embeddings
restaurant_embedding_matrix = np.load('restaurant_embeddings.npy')  # Load restaurant embeddings
attraction_embedding_matrix = np.load('attraction_embeddings.npy')  # Load attraction embeddings

# Prepare datasets for hotels, restaurants, and attractions
hotel_descriptions = hotel_df['description'].tolist()  # Hotel descriptions
restaurant_descriptions = restaurant_df['description'].tolist()  # Restaurant descriptions
attraction_descriptions = attraction_df['description'].tolist()  # Attraction descriptions

# Create datasets for each type
hotel_dataset = GPT2BERTDataset(hotel_descriptions, hotel_embedding_matrix, gpt_tokenizer)
restaurant_dataset = GPT2BERTDataset(restaurant_descriptions, restaurant_embedding_matrix, gpt_tokenizer)
attraction_dataset = GPT2BERTDataset(attraction_descriptions, attraction_embedding_matrix, gpt_tokenizer)

# Combine datasets into one
combined_dataset = ConcatDataset([hotel_dataset, restaurant_dataset, attraction_dataset])
dataloader = DataLoader(combined_dataset, batch_size=8, shuffle=True)

# Fine-tuning GPT-2 with BERT embeddings
optimizer = AdamW(gpt_model.parameters(), lr=5e-5,weight_decay=1e-2)

scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2, eta_min=1e-6)

# Training loop
for epoch in range(5):  # Adjust number of epochs as necessary
    gpt_model.train()
    total_loss = 0
    for batch_idx, batch in enumerate(dataloader):
        inputs, bert_embeddings = batch
        
        # Move tensors to the appropriate device (GPU if available)
        inputs = inputs.to(gpt_model.device)
        bert_embeddings = bert_embeddings.to(gpt_model.device)

        # Forward pass through GPT-2
        outputs = gpt_model(inputs, labels=inputs)
        
        # Calculate loss and backpropagate
        loss = outputs.loss
        total_loss += loss.item()  # Accumulate total loss
        optimizer.zero_grad()
        
        loss.backward()       
        # Apply gradient clipping
        torch.nn.utils.clip_grad_norm_(gpt_model.parameters(), max_norm=1.0)       
        # Update parameters and scheduler
        optimizer.step()
        scheduler.step()

    
        
        # Print details of each batch
        print(f"Epoch {epoch + 1}, Batch {batch_idx + 1}, Loss: {loss.item()}, Inputs shape: {inputs.shape}, Bert Embeddings shape: {bert_embeddings.shape}")

    # Print the average loss after each epoch
    average_loss = total_loss / len(dataloader)
    print(f"Epoch {epoch + 1} completed. Average Loss: {average_loss}")

# Save the fine-tuned GPT-2 model and tokenizer
gpt_model.save_pretrained('fine_tuned_gpt2')
gpt_tokenizer.save_pretrained('fine_tuned_gpt2')

def generate_response_gpt(prompt):
    inputs = gpt_tokenizer.encode(prompt, return_tensors='pt')
    with torch.no_grad():
        # Adjust the model to take embeddings into account if modified
        outputs = gpt_model.generate(inputs, max_length=100, num_return_sequences=1, temperature=0.7, top_p=0.9)
    
    response = gpt_tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(f"Generated Response: {response}")  # Print the generated response
    return response

# Example usage of the response generation
prompt = "What is the best hotel in Islamabad?"
generate_response_gpt(prompt)
# Out:
# C:\Users\aamir\anaconda3\Lib\site-packages\transformers\optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1, Batch 1, Loss: 7.114327430725098, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 2, Loss: 5.512115955352783, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 3, Loss: 4.516782283782959, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 4, Loss: 4.149557590484619, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 5, Loss: 3.452545404434204, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 6, Loss: 3.707782506942749, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 7, Loss: 3.983088970184326, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 8, Loss: 3.302690029144287, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 9, Loss: 3.308948278427124, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 10, Loss: 2.827997922897339, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 11, Loss: 2.9919614791870117, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 12, Loss: 2.8774821758270264, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 13, Loss: 2.495870351791382, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 14, Loss: 3.3457202911376953, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 15, Loss: 2.513127088546753, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 16, Loss: 2.9348480701446533, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 17, Loss: 2.6168527603149414, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 18, Loss: 3.1267008781433105, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 19, Loss: 3.297574043273926, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 20, Loss: 2.88285493850708, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 21, Loss: 2.7098031044006348, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 22, Loss: 2.578582525253296, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 23, Loss: 1.9743114709854126, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 24, Loss: 2.7888832092285156, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 25, Loss: 2.8165082931518555, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 26, Loss: 2.3691017627716064, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 27, Loss: 2.2391293048858643, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 28, Loss: 1.9201760292053223, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 29, Loss: 2.336554527282715, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 30, Loss: 2.1691501140594482, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 31, Loss: 2.0247387886047363, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 32, Loss: 2.6577630043029785, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 33, Loss: 2.8509738445281982, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 34, Loss: 2.456926107406616, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 35, Loss: 2.193934202194214, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 36, Loss: 2.3102381229400635, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 37, Loss: 1.6289141178131104, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 38, Loss: 2.1379308700561523, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 39, Loss: 2.387171983718872, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 40, Loss: 2.26667857170105, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 41, Loss: 1.8368034362792969, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 42, Loss: 1.9074182510375977, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 43, Loss: 1.8247170448303223, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 44, Loss: 1.9609363079071045, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 45, Loss: 1.697674036026001, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 46, Loss: 2.0583419799804688, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 47, Loss: 1.7720067501068115, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 48, Loss: 1.5920474529266357, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 49, Loss: 1.7730973958969116, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 50, Loss: 1.9639892578125, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 51, Loss: 1.5465424060821533, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 52, Loss: 2.149813413619995, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 53, Loss: 1.8411911725997925, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 54, Loss: 1.933915615081787, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 55, Loss: 1.378331184387207, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 56, Loss: 1.8750125169754028, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 57, Loss: 2.0866591930389404, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 58, Loss: 1.5518437623977661, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 59, Loss: 1.4596863985061646, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 60, Loss: 1.8505524396896362, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 61, Loss: 1.4404982328414917, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 62, Loss: 2.2349727153778076, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 63, Loss: 2.4107861518859863, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 64, Loss: 1.278630256652832, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 65, Loss: 1.8707971572875977, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 66, Loss: 2.0313968658447266, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 67, Loss: 1.5213603973388672, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 68, Loss: 2.5154757499694824, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 69, Loss: 1.8405040502548218, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 70, Loss: 1.668262004852295, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 71, Loss: 2.428090810775757, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 72, Loss: 1.5130658149719238, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 73, Loss: 1.624537467956543, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 74, Loss: 1.4670060873031616, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 75, Loss: 1.650712490081787, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 76, Loss: 1.764823317527771, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 77, Loss: 2.4840755462646484, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 78, Loss: 1.432532548904419, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 79, Loss: 1.3805996179580688, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 80, Loss: 1.8552119731903076, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 81, Loss: 1.7764527797698975, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 82, Loss: 1.5875579118728638, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 83, Loss: 1.7561324834823608, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 84, Loss: 1.6561696529388428, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 85, Loss: 2.1173956394195557, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 86, Loss: 1.844287633895874, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 87, Loss: 1.5125325918197632, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 88, Loss: 1.7595583200454712, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 89, Loss: 1.473248839378357, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 90, Loss: 1.856580376625061, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 91, Loss: 1.9329017400741577, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 92, Loss: 1.8524391651153564, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 93, Loss: 1.2816493511199951, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 94, Loss: 2.1711738109588623, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 95, Loss: 1.6044315099716187, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 96, Loss: 1.3922520875930786, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 97, Loss: 1.596303105354309, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 98, Loss: 1.6281744241714478, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 99, Loss: 1.8476234674453735, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 100, Loss: 1.9294264316558838, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 101, Loss: 2.0202646255493164, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 102, Loss: 1.2546206712722778, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 103, Loss: 1.568446159362793, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 104, Loss: 1.6546226739883423, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 105, Loss: 2.0586700439453125, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 106, Loss: 1.539627194404602, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 107, Loss: 1.670851230621338, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 108, Loss: 2.129049777984619, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 109, Loss: 1.8947162628173828, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 110, Loss: 1.8766491413116455, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 111, Loss: 1.4380117654800415, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 112, Loss: 1.875658631324768, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 113, Loss: 1.3776582479476929, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 114, Loss: 1.556265950202942, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 115, Loss: 1.586739420890808, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 116, Loss: 1.535956621170044, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 117, Loss: 1.406596302986145, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 118, Loss: 1.4621045589447021, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 119, Loss: 1.5458648204803467, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 120, Loss: 1.3681615591049194, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 121, Loss: 1.230305552482605, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 122, Loss: 1.3505996465682983, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 123, Loss: 1.9327880144119263, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 124, Loss: 1.4544761180877686, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 125, Loss: 1.6654783487319946, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 126, Loss: 1.4737880229949951, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 127, Loss: 1.6561554670333862, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 128, Loss: 1.7115589380264282, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 129, Loss: 1.1112332344055176, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 130, Loss: 1.7005658149719238, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 131, Loss: 1.1930248737335205, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 132, Loss: 1.741355299949646, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 133, Loss: 1.8350152969360352, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 134, Loss: 1.460493803024292, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 135, Loss: 1.4603227376937866, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 136, Loss: 1.4862933158874512, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 137, Loss: 1.6048641204833984, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 138, Loss: 1.7227332592010498, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 139, Loss: 1.1021504402160645, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 140, Loss: 1.5786653757095337, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 141, Loss: 1.4853203296661377, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 142, Loss: 1.3898241519927979, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 143, Loss: 1.665613055229187, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 144, Loss: 1.7070658206939697, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 145, Loss: 1.2249244451522827, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 146, Loss: 1.3884459733963013, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 147, Loss: 1.5061970949172974, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 148, Loss: 1.1209601163864136, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 149, Loss: 1.781067967414856, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 150, Loss: 1.0856610536575317, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 151, Loss: 1.4633371829986572, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 152, Loss: 1.6785743236541748, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 153, Loss: 1.5688180923461914, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 154, Loss: 1.5451459884643555, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 155, Loss: 1.318515658378601, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 156, Loss: 1.4837541580200195, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 157, Loss: 1.4012778997421265, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 158, Loss: 1.754304051399231, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 159, Loss: 1.4073317050933838, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 160, Loss: 1.1562857627868652, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 161, Loss: 1.2033305168151855, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 162, Loss: 1.385571837425232, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 163, Loss: 1.418055534362793, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 164, Loss: 1.683998942375183, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 165, Loss: 1.2095390558242798, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 166, Loss: 1.263378620147705, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 167, Loss: 1.8671919107437134, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 168, Loss: 1.7470399141311646, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 169, Loss: 1.2348159551620483, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 170, Loss: 1.7959829568862915, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 171, Loss: 1.5409878492355347, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 172, Loss: 1.7079709768295288, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 173, Loss: 1.6334413290023804, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 174, Loss: 1.7379441261291504, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 175, Loss: 1.4524540901184082, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 176, Loss: 1.4245095252990723, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 177, Loss: 1.5356602668762207, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 178, Loss: 1.7176307439804077, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 179, Loss: 1.636794924736023, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 180, Loss: 1.0722548961639404, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 181, Loss: 1.7358613014221191, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 182, Loss: 1.3485077619552612, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 183, Loss: 1.2137871980667114, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 184, Loss: 1.3510515689849854, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 185, Loss: 1.5491423606872559, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 186, Loss: 1.2332159280776978, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 187, Loss: 1.4593347311019897, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 188, Loss: 1.1305557489395142, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 189, Loss: 1.6463186740875244, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 190, Loss: 1.1824771165847778, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 191, Loss: 1.4673540592193604, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 192, Loss: 1.436555027961731, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 193, Loss: 1.368592381477356, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 194, Loss: 1.2477775812149048, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 195, Loss: 1.1879488229751587, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 196, Loss: 1.5154892206192017, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 197, Loss: 1.3974977731704712, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 198, Loss: 1.3047785758972168, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 199, Loss: 1.227099061012268, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 200, Loss: 1.6174215078353882, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 201, Loss: 1.0930794477462769, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 202, Loss: 1.4245679378509521, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 203, Loss: 1.7467119693756104, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 204, Loss: 1.2005805969238281, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 205, Loss: 1.6360785961151123, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 206, Loss: 1.4160692691802979, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 207, Loss: 1.3557344675064087, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 208, Loss: 1.7410616874694824, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 209, Loss: 2.4726834297180176, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 210, Loss: 1.4613748788833618, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 211, Loss: 1.4721599817276, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 212, Loss: 1.0275894403457642, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 213, Loss: 1.832754135131836, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 214, Loss: 1.362900733947754, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 215, Loss: 1.533665657043457, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 216, Loss: 1.281882882118225, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 217, Loss: 1.4976633787155151, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 218, Loss: 1.342550277709961, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 219, Loss: 1.7499074935913086, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 220, Loss: 1.2083364725112915, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 221, Loss: 1.5608761310577393, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 222, Loss: 1.6973930597305298, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 223, Loss: 1.1815096139907837, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 224, Loss: 1.0570272207260132, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 225, Loss: 1.5783090591430664, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 226, Loss: 1.0442177057266235, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 227, Loss: 1.7736247777938843, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 228, Loss: 1.348786473274231, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 229, Loss: 1.1542932987213135, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 230, Loss: 1.3339776992797852, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 231, Loss: 1.847481608390808, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 232, Loss: 1.270414113998413, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 233, Loss: 0.8932269215583801, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 234, Loss: 1.7801575660705566, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 235, Loss: 1.0755431652069092, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 236, Loss: 1.3323068618774414, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 237, Loss: 1.490999460220337, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 238, Loss: 1.496824026107788, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 239, Loss: 1.2361310720443726, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 240, Loss: 1.7863647937774658, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 241, Loss: 1.4128937721252441, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 242, Loss: 1.5286515951156616, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 243, Loss: 1.6494747400283813, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 244, Loss: 1.0511815547943115, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 245, Loss: 1.1826457977294922, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 246, Loss: 1.3363536596298218, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 247, Loss: 0.9964284300804138, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 248, Loss: 1.4061822891235352, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 249, Loss: 1.2766345739364624, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 250, Loss: 1.4170206785202026, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 251, Loss: 1.6432849168777466, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 252, Loss: 1.348135232925415, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 253, Loss: 1.2028131484985352, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 254, Loss: 1.2180302143096924, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 255, Loss: 1.1848384141921997, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 256, Loss: 1.2969595193862915, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 257, Loss: 1.1774417161941528, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 258, Loss: 1.3293455839157104, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 259, Loss: 1.4284324645996094, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 260, Loss: 1.2109746932983398, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 261, Loss: 1.51042640209198, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 262, Loss: 1.2474026679992676, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 263, Loss: 1.233762264251709, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 264, Loss: 1.4311727285385132, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 265, Loss: 1.3765175342559814, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 266, Loss: 1.340806484222412, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 267, Loss: 1.3694589138031006, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 268, Loss: 1.18489670753479, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 269, Loss: 1.551835298538208, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 270, Loss: 1.5507280826568604, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 271, Loss: 1.177446722984314, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 272, Loss: 1.6143248081207275, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 273, Loss: 1.6221787929534912, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 274, Loss: 1.1944507360458374, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 275, Loss: 1.2593810558319092, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 276, Loss: 1.4937465190887451, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 277, Loss: 1.43275785446167, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 278, Loss: 1.2176127433776855, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 279, Loss: 1.2154591083526611, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 280, Loss: 1.5725429058074951, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 281, Loss: 1.23172128200531, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 282, Loss: 1.433946132659912, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 283, Loss: 1.5295696258544922, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 284, Loss: 1.7963626384735107, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 285, Loss: 1.0371862649917603, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 286, Loss: 1.3200284242630005, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 287, Loss: 1.1652915477752686, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 288, Loss: 0.8619643449783325, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 289, Loss: 1.0048595666885376, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 290, Loss: 1.1796821355819702, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 291, Loss: 1.5003103017807007, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 292, Loss: 1.5337802171707153, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 293, Loss: 1.2885353565216064, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 294, Loss: 0.8934057950973511, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 295, Loss: 1.5541514158248901, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 296, Loss: 2.103475332260132, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 297, Loss: 1.3177028894424438, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 298, Loss: 1.1476905345916748, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 299, Loss: 1.201857566833496, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 300, Loss: 1.2323615550994873, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 301, Loss: 1.1829900741577148, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 302, Loss: 0.9360488653182983, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 303, Loss: 1.4882822036743164, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 304, Loss: 0.9329174160957336, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 305, Loss: 1.4485893249511719, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 306, Loss: 1.2623214721679688, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 307, Loss: 1.527127981185913, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 308, Loss: 1.6284173727035522, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 309, Loss: 1.5940912961959839, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 310, Loss: 1.0930368900299072, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 311, Loss: 1.073471188545227, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 312, Loss: 1.1779009103775024, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 313, Loss: 1.3400501012802124, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 314, Loss: 1.222746729850769, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 315, Loss: 1.0005710124969482, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 316, Loss: 1.565194010734558, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 317, Loss: 1.2005418539047241, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 318, Loss: 1.2818692922592163, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 319, Loss: 1.5363978147506714, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 320, Loss: 1.1766387224197388, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 321, Loss: 1.0056554079055786, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 322, Loss: 1.472399115562439, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 323, Loss: 1.5925376415252686, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 324, Loss: 1.0459201335906982, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 325, Loss: 1.0098373889923096, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 326, Loss: 1.4096431732177734, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 327, Loss: 1.5533536672592163, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 328, Loss: 1.097135305404663, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 329, Loss: 1.610516905784607, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 330, Loss: 1.2575942277908325, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 331, Loss: 1.5368708372116089, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 332, Loss: 1.6627826690673828, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 333, Loss: 1.2623677253723145, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 334, Loss: 1.2934752702713013, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 335, Loss: 1.1530702114105225, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 336, Loss: 1.3917962312698364, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 337, Loss: 1.3528022766113281, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 338, Loss: 1.434547781944275, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 339, Loss: 1.477317214012146, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 340, Loss: 1.234164834022522, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 341, Loss: 1.3146202564239502, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 342, Loss: 1.0984708070755005, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 343, Loss: 1.2425589561462402, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 344, Loss: 1.8819117546081543, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 345, Loss: 1.5040031671524048, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 346, Loss: 1.1657406091690063, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 347, Loss: 1.2936131954193115, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 348, Loss: 1.6351127624511719, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 349, Loss: 1.4869548082351685, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 350, Loss: 1.463452935218811, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 351, Loss: 1.3844900131225586, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 352, Loss: 0.9876793026924133, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 353, Loss: 1.3841930627822876, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 354, Loss: 1.403140902519226, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 355, Loss: 1.4445257186889648, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 356, Loss: 1.2713029384613037, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 357, Loss: 1.073134183883667, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 358, Loss: 1.228861927986145, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 359, Loss: 1.590401291847229, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 360, Loss: 1.3324079513549805, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 361, Loss: 1.4588321447372437, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 362, Loss: 1.6775877475738525, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 363, Loss: 1.0918364524841309, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 364, Loss: 1.6160794496536255, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 365, Loss: 0.8538665771484375, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 366, Loss: 1.5594844818115234, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 367, Loss: 1.4639593362808228, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 368, Loss: 1.1261571645736694, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 369, Loss: 1.2635923624038696, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 370, Loss: 1.1286532878875732, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 371, Loss: 1.2394740581512451, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 372, Loss: 1.48533296585083, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 373, Loss: 1.003784418106079, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 374, Loss: 0.9679917693138123, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 375, Loss: 1.5655229091644287, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 376, Loss: 1.6505078077316284, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 377, Loss: 1.20626962184906, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 378, Loss: 1.2144405841827393, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 379, Loss: 1.2230831384658813, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 380, Loss: 1.1806308031082153, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# ...
# Epoch 3, Batch 650, Loss: 1.2106305360794067, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 651, Loss: 0.8790243864059448, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 652, Loss: 0.9073359966278076, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 653, Loss: 0.7118510007858276, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 654, Loss: 1.106438159942627, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 655, Loss: 0.9071820974349976, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 656, Loss: 0.9122495651245117, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 657, Loss: 0.7127518057823181, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 658, Loss: 0.8954657912254333, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 659, Loss: 0.9297122955322266, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 660, Loss: 0.7733211517333984, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 661, Loss: 0.8665227890014648, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 662, Loss: 1.0823920965194702, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 663, Loss: 0.9120031595230103, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 664, Loss: 0.8803846836090088, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 665, Loss: 0.8341501951217651, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 666, Loss: 0.6962869763374329, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 667, Loss: 0.8497443795204163, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 668, Loss: 0.8185193538665771, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 669, Loss: 0.7879433035850525, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 670, Loss: 0.9013681411743164, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 671, Loss: 1.2854033708572388, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 672, Loss: 0.9480879306793213, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 673, Loss: 0.8567386865615845, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 674, Loss: 0.9310052394866943, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 675, Loss: 0.9681283235549927, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 676, Loss: 0.9743938446044922, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 677, Loss: 0.7688121795654297, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 678, Loss: 1.1891179084777832, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 679, Loss: 1.1518574953079224, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 680, Loss: 1.1593132019042969, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 681, Loss: 0.9172846674919128, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 682, Loss: 0.8192753791809082, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 683, Loss: 0.9895159602165222, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 684, Loss: 1.11202073097229, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 685, Loss: 0.9848206639289856, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 686, Loss: 1.1404169797897339, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 687, Loss: 0.9701893329620361, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 688, Loss: 0.9655620455741882, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 689, Loss: 0.9624404311180115, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 690, Loss: 1.1396082639694214, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 691, Loss: 1.0957461595535278, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 692, Loss: 0.8052523136138916, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 693, Loss: 0.8621278405189514, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 694, Loss: 0.7304090857505798, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 695, Loss: 1.171183466911316, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 696, Loss: 0.8740224242210388, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 697, Loss: 0.9432782530784607, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 698, Loss: 1.0420427322387695, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 699, Loss: 1.2598206996917725, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 700, Loss: 0.6932122111320496, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 701, Loss: 1.0374741554260254, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 702, Loss: 0.7968109846115112, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 703, Loss: 0.7894981503486633, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 704, Loss: 0.7592344284057617, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 705, Loss: 1.0515527725219727, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 706, Loss: 1.0626397132873535, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 707, Loss: 0.8614517450332642, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 708, Loss: 0.8740981817245483, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 709, Loss: 1.2757216691970825, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 710, Loss: 0.9488651752471924, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 711, Loss: 0.8252127170562744, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 712, Loss: 1.0305277109146118, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 713, Loss: 1.086925983428955, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 714, Loss: 0.8950414061546326, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 715, Loss: 1.344847559928894, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 716, Loss: 1.01828932762146, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 717, Loss: 0.9767298698425293, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 718, Loss: 1.105092167854309, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 719, Loss: 0.8808810114860535, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 720, Loss: 1.2212291955947876, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 721, Loss: 0.7311431169509888, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 722, Loss: 0.6797312498092651, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 723, Loss: 0.9702335000038147, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 724, Loss: 0.85273277759552, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 725, Loss: 0.9820696711540222, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 726, Loss: 0.9600498080253601, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 727, Loss: 0.9558575749397278, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 728, Loss: 0.8838552832603455, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 729, Loss: 0.9728404879570007, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 730, Loss: 1.0052449703216553, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 731, Loss: 0.7857122421264648, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 732, Loss: 0.8435207605361938, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 733, Loss: 0.9286864399909973, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 734, Loss: 0.8516372442245483, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 735, Loss: 0.764369785785675, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 736, Loss: 1.074988603591919, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 737, Loss: 0.9436531662940979, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 738, Loss: 1.149821162223816, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 739, Loss: 0.8494269847869873, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 740, Loss: 0.7731304168701172, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 741, Loss: 0.8593106269836426, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 742, Loss: 1.0005924701690674, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 743, Loss: 1.2176322937011719, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 744, Loss: 0.8077176213264465, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 745, Loss: 0.8916032314300537, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 746, Loss: 1.03159761428833, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 747, Loss: 1.0421401262283325, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 748, Loss: 1.0569685697555542, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 749, Loss: 0.9551604986190796, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 750, Loss: 0.8697533011436462, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 751, Loss: 0.8058755397796631, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 752, Loss: 0.876226007938385, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 753, Loss: 1.054991602897644, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 754, Loss: 1.0385994911193848, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 755, Loss: 1.3192195892333984, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 756, Loss: 1.194317102432251, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 757, Loss: 1.1877700090408325, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 758, Loss: 0.8710898160934448, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 759, Loss: 0.7939167022705078, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 760, Loss: 1.1844736337661743, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 761, Loss: 0.8709627389907837, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 762, Loss: 0.7600600123405457, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 3, Batch 763, Loss: 1.0097843408584595, Inputs shape: torch.Size([2, 100]), Bert Embeddings shape: torch.Size([2, 768])
# Epoch 3 completed. Average Loss: 0.9501372538262863
# C:\Users\aamir\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# C:\Users\aamir\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Generated Response: What is the best hotel in Islamabad? and its address is address not available in Islamabad, costing Rs12648 per night. Small description: Check-in time: 14:00Check-out time: 12:00. Available facilities: Conference Room, Spa, Free Wi-Fi.
# 'What is the best hotel in Islamabad? and its address is address not available in Islamabad, costing Rs12648 per night. Small description: Check-in time: 14:00Check-out time: 12:00. Available facilities: Conference Room, Spa, Free Wi-Fi.'

# %%
import numpy as np
from transformers import GPT2Tokenizer, GPT2LMHeadModel, AdamW

from torch.utils.data import Dataset, DataLoader, ConcatDataset
import pandas as pd
import re
import torch
from sklearn.metrics.pairwise import cosine_similarity
import os
from nltk.corpus import wordnet as wn
import nltk
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts



# Load data from files and handle missing data
def load_data(file_path, file_type='csv'):
    if not os.path.exists(file_path):
        print(f"Error: {file_path} not found.")
        return None
    try:
        if file_type == 'csv':
            return pd.read_csv(file_path)
        elif file_type == 'json':
            return pd.read_json(file_path)
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None

# Load all required datasets
hotel_df = load_data('new_hotel_data.csv')
ratings_df = load_data('clean_hotel_review_data.json', 'json')
restaurant_df = load_data('new_restaurant_db.restaurants_data.json', 'json')
attraction_df = load_data('attraction.csv')
if hotel_df is None or ratings_df is None or restaurant_df is None or attraction_df is None:
    print("Error: One or more required datasets are missing or improperly loaded. Please check your data files.")
    exit()

# Merge hotel ratings with hotel data on 'hotel_id'
merged_df = hotel_df.merge(ratings_df, on='hotel_id', how='left')
average_ratings = merged_df.groupby('hotel_id')['rating'].mean().reset_index()
average_ratings.columns = ['hotel_id', 'average_rating']
hotel_df = hotel_df.merge(average_ratings, on='hotel_id', how='left')
hotel_df.rename(columns={'average_rating': 'Rating'}, inplace=True)

restaurant_ratings_df = load_data('new_restaurant_db.restaurants_reviews.json', 'json')
restaurant_merged_df = restaurant_df.merge(restaurant_ratings_df, on='restaurant_id', how='left')
average_restaurant_ratings = restaurant_merged_df.groupby('restaurant_id')['rating'].mean().reset_index()
average_restaurant_ratings.columns = ['restaurant_id', 'average_restaurant_ratings']
restaurant_df = restaurant_df.merge(average_restaurant_ratings, on='restaurant_id', how='left')
restaurant_df.rename(columns={'average_restaurant_ratings': 'Rating'}, inplace=True)
restaurant_df['Rating'] = restaurant_df['Rating'].fillna(3.5)

# List of facilities
facilities_list = ['Cable TV', 'Entire apartment', 'Oven stove', 'Car Rental Service', 'Ironing board', 
                   'bathroom', 'Washing machine', 'Cot', 'Entire bungalow', 'Conference Room', 
                   'Fitness Center', 'Outdoor grill', 'Fitness centre', 'Pet-friendly', 'Entire house',
                   'Pet Friendly', 'Airport shuttle', 'Terrace', 'Room Service', 'BBQ Facilities', 
                   '24-Hour Front Desk', 'Child-friendly', 'Kitchen', 'Microwave', 'Free parking', 
                   'Breakfast Buffet', 'Swimming Pool', 'Paid parking', 'Entire villa', 'Air conditioning', 
                   'Balcony', 'Spa', 'Business Center', 'Free breakfast', 'Currency Exchange', 
                   'Outdoor pool', 'Air Conditioning', 'Laundry', 'Golf Course', 'cafe', 'Indoor pool', 
                   'Parking', 'Garden', 'Patio', 'Fireplace', 'Restaurant', 'Smoking Rooms', 
                   'Babysitting Service', 'Heating', 'Paid Wi-Fi', 'Wheelchair accessible', 'Entire chalet', 
                   'Lift', 'Smoke-free', 'Entire cottage', 'Library', 'Hot tub', 'Beach access', 
                   'Family Rooms', 'Free Wi-Fi']


def preprocess_hotel_data(row):
    description = f"{row['name']} and its address is {row['address']} in {row['city']}, costing Rs{row['price']} per night. Small description: {row['about']}."
    available_facilities = [facility for facility in facilities_list if row.get(facility, 0) == 1]
    if available_facilities:
        description += " Available facilities: " + ", ".join(available_facilities) + "."
    else:
        description += " No special facilities are listed."
    return description.strip()

hotel_df['description'] = hotel_df.apply(preprocess_hotel_data, axis=1)

def preprocess_restaurant_data(row):
    return f"{row['name']} located at {row['address']} and its phone number is {row['phone_number']} in {row['city']}. The provided services are {row['service']} and opening hour is {row['Open_hour']}."

def preprocess_attraction_data(row):
    return f"{row['Name']} is a popular attraction located in {row['city']}. Its address is {row['Address']}, its category is {row['Category']}, its rating is {row['Rating']}, and its availability time is {row['Availability']}. Description: {row['Description']}."

restaurant_df['description'] = restaurant_df.apply(preprocess_restaurant_data, axis=1)
attraction_df['description'] = attraction_df.apply(preprocess_attraction_data, axis=1)





# Load the GPT-2 tokenizer and model
gpt_tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
gpt_model = GPT2LMHeadModel.from_pretrained('gpt2')

# Set the padding token for the GPT-2 tokenizer
gpt_tokenizer.pad_token = gpt_tokenizer.eos_token  # Set padding token to EOS token

class GPT2BERTDataset(Dataset):
    def __init__(self, descriptions, embeddings, tokenizer):
        self.descriptions = descriptions
        self.embeddings = embeddings
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.descriptions)

    def __getitem__(self, idx):
        # Convert text description to tokens
        description = self.descriptions[idx]
        embedding = self.embeddings[idx]
        
        # Tokenize description with padding
        tokenized_input = self.tokenizer.encode(description, return_tensors='pt', padding='max_length', max_length=100, truncation=True).squeeze(0)
        
        return tokenized_input, torch.tensor(embedding, dtype=torch.float32)

# Load embeddings from the specified files
hotel_embedding_matrix = np.load('hotel_embeddings.npy')  # Load hotel embeddings
restaurant_embedding_matrix = np.load('restaurant_embeddings.npy')  # Load restaurant embeddings
attraction_embedding_matrix = np.load('attraction_embeddings.npy')  # Load attraction embeddings

# Prepare datasets for hotels, restaurants, and attractions
hotel_descriptions = hotel_df['description'].tolist()  # Hotel descriptions
restaurant_descriptions = restaurant_df['description'].tolist()  # Restaurant descriptions
attraction_descriptions = attraction_df['description'].tolist()  # Attraction descriptions

# Create datasets for each type
hotel_dataset = GPT2BERTDataset(hotel_descriptions, hotel_embedding_matrix, gpt_tokenizer)
restaurant_dataset = GPT2BERTDataset(restaurant_descriptions, restaurant_embedding_matrix, gpt_tokenizer)
attraction_dataset = GPT2BERTDataset(attraction_descriptions, attraction_embedding_matrix, gpt_tokenizer)

# Combine datasets into one
combined_dataset = ConcatDataset([hotel_dataset, restaurant_dataset, attraction_dataset])
dataloader = DataLoader(combined_dataset, batch_size=8, shuffle=True)

# Fine-tuning GPT-2 with BERT embeddings
optimizer = AdamW(gpt_model.parameters(), lr=5e-5,weight_decay=1e-2)

scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2, eta_min=1e-6)

# Training loop
for epoch in range(5):  # Adjust number of epochs as necessary
    gpt_model.train()
    total_loss = 0
    for batch_idx, batch in enumerate(dataloader):
        inputs, bert_embeddings = batch
        
        # Move tensors to the appropriate device (GPU if available)
        inputs = inputs.to(gpt_model.device)
        bert_embeddings = bert_embeddings.to(gpt_model.device)

        # Forward pass through GPT-2
        outputs = gpt_model(inputs, labels=inputs)
        
        # Calculate loss and backpropagate
        loss = outputs.loss
        total_loss += loss.item()  # Accumulate total loss
        optimizer.zero_grad()
        
        loss.backward()       
        # Apply gradient clipping
        torch.nn.utils.clip_grad_norm_(gpt_model.parameters(), max_norm=1.0)       
        # Update parameters and scheduler
        optimizer.step()
        scheduler.step()

    
        
        # Print details of each batch
        print(f"Epoch {epoch + 1}, Batch {batch_idx + 1}, Loss: {loss.item()}, Inputs shape: {inputs.shape}, Bert Embeddings shape: {bert_embeddings.shape}")

    # Print the average loss after each epoch
    average_loss = total_loss / len(dataloader)
    print(f"Epoch {epoch + 1} completed. Average Loss: {average_loss}")

# Save the fine-tuned GPT-2 model and tokenizer
gpt_model.save_pretrained('fine_tuned_gpt2')
gpt_tokenizer.save_pretrained('fine_tuned_gpt2')

def generate_response_gpt(prompt):
    inputs = gpt_tokenizer.encode(prompt, return_tensors='pt')
    with torch.no_grad():
        # Adjust the model to take embeddings into account if modified
        outputs = gpt_model.generate(inputs, max_length=100, num_return_sequences=1, temperature=0.7, top_p=0.9)
    
    response = gpt_tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(f"Generated Response: {response}")  # Print the generated response
    return response

# Example usage of the response generation
prompt = "What is the best hotel in Islamabad?"
generate_response_gpt(prompt)
# Out:
# C:\Users\aamir\anaconda3\Lib\site-packages\transformers\optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1, Batch 1, Loss: 7.442346572875977, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 2, Loss: 6.737992763519287, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 3, Loss: 5.2877092361450195, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 4, Loss: 4.9482269287109375, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 5, Loss: 4.0254998207092285, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 6, Loss: 4.365288734436035, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 7, Loss: 4.031280517578125, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 8, Loss: 4.055359840393066, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 9, Loss: 3.8109443187713623, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 10, Loss: 4.103360652923584, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 11, Loss: 3.826054334640503, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 12, Loss: 3.4099886417388916, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 13, Loss: 3.6698720455169678, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 14, Loss: 3.2869086265563965, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 15, Loss: 3.7472541332244873, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 16, Loss: 3.0039801597595215, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 17, Loss: 3.273024797439575, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 18, Loss: 3.068047523498535, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 19, Loss: 3.256711006164551, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 20, Loss: 3.2087790966033936, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 21, Loss: 3.3774466514587402, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 22, Loss: 3.711606979370117, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 23, Loss: 3.4077565670013428, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 24, Loss: 2.8820223808288574, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 25, Loss: 2.4171485900878906, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 26, Loss: 3.3737118244171143, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 27, Loss: 2.3940906524658203, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 28, Loss: 3.028165340423584, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 29, Loss: 3.590639114379883, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 30, Loss: 2.7910995483398438, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 31, Loss: 2.3089075088500977, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 32, Loss: 2.8609015941619873, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 33, Loss: 2.6497395038604736, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 34, Loss: 2.1585006713867188, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 35, Loss: 2.6016311645507812, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 36, Loss: 2.846917152404785, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 37, Loss: 2.7332234382629395, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 38, Loss: 2.2670207023620605, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 39, Loss: 2.289731025695801, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 40, Loss: 2.54374361038208, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 41, Loss: 2.5051798820495605, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 42, Loss: 2.1873056888580322, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 43, Loss: 2.2165660858154297, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 44, Loss: 2.1376073360443115, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 45, Loss: 1.48627507686615, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 46, Loss: 2.2730705738067627, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 47, Loss: 2.3989224433898926, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 48, Loss: 2.4026808738708496, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 49, Loss: 2.011505126953125, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 50, Loss: 2.012681722640991, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 51, Loss: 1.7519127130508423, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 52, Loss: 2.1098508834838867, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 53, Loss: 2.2200400829315186, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 54, Loss: 2.1483871936798096, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 55, Loss: 2.4516003131866455, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 56, Loss: 2.324113130569458, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 57, Loss: 2.0758440494537354, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 58, Loss: 2.4477694034576416, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 59, Loss: 2.3424172401428223, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 60, Loss: 2.4541592597961426, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 61, Loss: 2.538926601409912, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 62, Loss: 1.9342551231384277, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 63, Loss: 1.8044506311416626, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 64, Loss: 1.9924476146697998, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 65, Loss: 1.9601887464523315, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 66, Loss: 1.8359375, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 67, Loss: 1.8760249614715576, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 68, Loss: 2.7248401641845703, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 69, Loss: 2.1096761226654053, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 70, Loss: 2.0419111251831055, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 71, Loss: 1.9983859062194824, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 72, Loss: 2.3391525745391846, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 73, Loss: 2.1858155727386475, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 74, Loss: 1.8137260675430298, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 75, Loss: 2.2763819694519043, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 76, Loss: 1.8391932249069214, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 77, Loss: 1.9791096448898315, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 78, Loss: 1.7235243320465088, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 79, Loss: 1.5188065767288208, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 80, Loss: 1.7428550720214844, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 81, Loss: 2.1148297786712646, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 82, Loss: 2.0309085845947266, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 83, Loss: 1.1504815816879272, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 84, Loss: 1.9145193099975586, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 85, Loss: 1.5943251848220825, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 86, Loss: 2.0679807662963867, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 87, Loss: 1.850624918937683, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 88, Loss: 2.279219388961792, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 89, Loss: 2.2736663818359375, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 90, Loss: 2.0622191429138184, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 91, Loss: 1.8746342658996582, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 92, Loss: 2.061398983001709, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 93, Loss: 1.796195149421692, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 94, Loss: 2.0754637718200684, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 95, Loss: 1.9611068964004517, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 96, Loss: 1.2837152481079102, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 97, Loss: 2.036581039428711, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 98, Loss: 1.7822303771972656, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 99, Loss: 1.3135368824005127, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 100, Loss: 1.842952847480774, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 101, Loss: 1.3337390422821045, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 102, Loss: 1.5160454511642456, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 103, Loss: 1.424207329750061, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 104, Loss: 2.2152814865112305, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 105, Loss: 1.8094559907913208, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 106, Loss: 1.6488206386566162, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 107, Loss: 2.2220187187194824, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 108, Loss: 1.7133375406265259, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 109, Loss: 2.103026866912842, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 110, Loss: 1.8887819051742554, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 111, Loss: 1.7668782472610474, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 112, Loss: 1.5467833280563354, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 113, Loss: 2.338482141494751, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 114, Loss: 1.6301634311676025, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 115, Loss: 1.6896998882293701, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 116, Loss: 1.6799513101577759, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 117, Loss: 1.9436461925506592, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 118, Loss: 1.646373987197876, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 119, Loss: 2.183199167251587, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 120, Loss: 1.5508763790130615, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 121, Loss: 1.8408833742141724, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 122, Loss: 1.4680742025375366, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 123, Loss: 1.6403123140335083, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 124, Loss: 1.4081803560256958, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 125, Loss: 1.2316343784332275, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 126, Loss: 1.5056447982788086, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 127, Loss: 1.7714594602584839, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 128, Loss: 1.2432494163513184, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 129, Loss: 1.4774891138076782, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 130, Loss: 2.161669969558716, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 131, Loss: 1.7249524593353271, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 132, Loss: 1.7304850816726685, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 133, Loss: 1.4237709045410156, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 134, Loss: 1.5263808965682983, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 135, Loss: 1.6943174600601196, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 136, Loss: 1.5804400444030762, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 137, Loss: 1.9463016986846924, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 138, Loss: 1.6941813230514526, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 139, Loss: 1.6457865238189697, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 140, Loss: 1.3315354585647583, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 141, Loss: 1.7360187768936157, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 142, Loss: 2.323153018951416, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 143, Loss: 2.0416653156280518, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 144, Loss: 1.095842957496643, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 145, Loss: 1.2953232526779175, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 146, Loss: 1.6008310317993164, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 147, Loss: 2.261882781982422, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 148, Loss: 1.9311002492904663, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 149, Loss: 1.7520129680633545, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 150, Loss: 1.532551884651184, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 151, Loss: 2.1325125694274902, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 152, Loss: 1.570997714996338, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 153, Loss: 1.6077845096588135, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 154, Loss: 1.4780150651931763, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 155, Loss: 1.602878451347351, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 156, Loss: 2.0694761276245117, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 157, Loss: 1.9553308486938477, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 158, Loss: 1.503167986869812, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 159, Loss: 1.6793246269226074, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 160, Loss: 1.7231866121292114, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 161, Loss: 1.9886174201965332, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 162, Loss: 1.515757441520691, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 163, Loss: 1.6557005643844604, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 164, Loss: 1.5605709552764893, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 165, Loss: 1.8007913827896118, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 166, Loss: 1.6086509227752686, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 167, Loss: 1.6678931713104248, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 168, Loss: 1.7897127866744995, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 169, Loss: 1.2987008094787598, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 170, Loss: 1.927194595336914, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 171, Loss: 1.5494822263717651, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 172, Loss: 1.594131588935852, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 173, Loss: 1.7996937036514282, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 174, Loss: 1.4272841215133667, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 175, Loss: 1.4731104373931885, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 176, Loss: 1.5876129865646362, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 177, Loss: 1.9990761280059814, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 178, Loss: 1.340053677558899, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 179, Loss: 1.550454020500183, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 180, Loss: 1.6347267627716064, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 181, Loss: 1.3430829048156738, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 182, Loss: 1.6012235879898071, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 183, Loss: 1.098490834236145, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 184, Loss: 1.6027504205703735, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 185, Loss: 1.4255480766296387, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 186, Loss: 1.4105515480041504, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 187, Loss: 1.6154911518096924, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 188, Loss: 1.4966868162155151, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 189, Loss: 2.0233399868011475, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 190, Loss: 1.5558491945266724, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 191, Loss: 1.402106523513794, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 192, Loss: 1.2336182594299316, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 193, Loss: 1.2551857233047485, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 194, Loss: 1.6159414052963257, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 195, Loss: 1.0786620378494263, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 196, Loss: 1.6097280979156494, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 197, Loss: 1.3635884523391724, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 198, Loss: 1.5088833570480347, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 199, Loss: 1.2889149188995361, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 200, Loss: 1.7005800008773804, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 201, Loss: 1.3526028394699097, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 202, Loss: 1.177661657333374, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 203, Loss: 1.4374009370803833, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 204, Loss: 1.5665998458862305, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 205, Loss: 1.494297981262207, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 206, Loss: 1.2124446630477905, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 207, Loss: 1.4235780239105225, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 208, Loss: 1.7120682001113892, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 209, Loss: 1.4810864925384521, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 210, Loss: 1.6978176832199097, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 211, Loss: 1.469062089920044, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 212, Loss: 1.3177226781845093, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 213, Loss: 1.864890456199646, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 214, Loss: 1.4517308473587036, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 215, Loss: 1.6509231328964233, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 216, Loss: 1.5694572925567627, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 217, Loss: 1.3930226564407349, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 218, Loss: 1.6794400215148926, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 219, Loss: 1.4676097631454468, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 220, Loss: 1.6788520812988281, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 221, Loss: 1.4785207509994507, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 222, Loss: 2.1402981281280518, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 223, Loss: 1.4166301488876343, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 224, Loss: 1.3050237894058228, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 225, Loss: 1.3314846754074097, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 226, Loss: 1.4453635215759277, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 227, Loss: 1.4596532583236694, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 228, Loss: 1.306801438331604, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 229, Loss: 1.6837048530578613, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 230, Loss: 1.7956490516662598, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 231, Loss: 1.3481851816177368, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 232, Loss: 1.4969055652618408, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 233, Loss: 1.5401374101638794, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 234, Loss: 1.6901065111160278, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 235, Loss: 1.624479055404663, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 236, Loss: 1.4319720268249512, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 237, Loss: 1.4660766124725342, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 238, Loss: 1.543447494506836, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 239, Loss: 1.3852580785751343, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 240, Loss: 1.1840444803237915, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 241, Loss: 1.3240618705749512, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 242, Loss: 1.4294719696044922, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 243, Loss: 1.108394980430603, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 244, Loss: 1.4133925437927246, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 245, Loss: 1.2165254354476929, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 246, Loss: 1.3645588159561157, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 247, Loss: 1.3463733196258545, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 248, Loss: 1.3724896907806396, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 249, Loss: 1.952438235282898, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 250, Loss: 1.5602295398712158, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 251, Loss: 1.203334093093872, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 252, Loss: 1.8246923685073853, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 253, Loss: 1.5744750499725342, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 254, Loss: 1.537543535232544, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 255, Loss: 1.2917484045028687, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 256, Loss: 1.7573885917663574, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 257, Loss: 1.6196579933166504, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 258, Loss: 1.9053267240524292, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 259, Loss: 1.5950597524642944, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 260, Loss: 1.3916319608688354, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 261, Loss: 1.7477754354476929, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 262, Loss: 1.9559701681137085, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 263, Loss: 1.411596417427063, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 264, Loss: 1.4935665130615234, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 265, Loss: 1.2304328680038452, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 266, Loss: 1.3964269161224365, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 267, Loss: 1.1662572622299194, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 268, Loss: 1.1468055248260498, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 269, Loss: 1.0459173917770386, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 270, Loss: 1.7030223608016968, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 271, Loss: 1.2470859289169312, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 272, Loss: 2.0125529766082764, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 273, Loss: 1.7152457237243652, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 274, Loss: 1.6877532005310059, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 275, Loss: 1.4020047187805176, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 276, Loss: 1.523364543914795, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 277, Loss: 1.0785475969314575, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 278, Loss: 1.4144350290298462, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 279, Loss: 1.4868910312652588, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 280, Loss: 1.297685980796814, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 281, Loss: 1.529440999031067, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 282, Loss: 1.363353967666626, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 283, Loss: 1.246535062789917, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 284, Loss: 1.4487338066101074, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 285, Loss: 1.3162411451339722, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 286, Loss: 1.323087453842163, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 287, Loss: 1.5798044204711914, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 288, Loss: 1.3441252708435059, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 289, Loss: 0.7905306816101074, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 290, Loss: 1.374656319618225, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 291, Loss: 1.170738935470581, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 292, Loss: 1.201396107673645, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 293, Loss: 1.5548280477523804, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 294, Loss: 1.8467179536819458, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 295, Loss: 1.3923511505126953, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 296, Loss: 1.6054636240005493, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 297, Loss: 1.5006173849105835, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 298, Loss: 1.4131863117218018, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 299, Loss: 1.5749237537384033, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 300, Loss: 1.8056138753890991, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 301, Loss: 1.2886900901794434, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 302, Loss: 1.1873972415924072, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 303, Loss: 1.2795921564102173, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 304, Loss: 1.4379066228866577, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 305, Loss: 1.245980978012085, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 306, Loss: 1.3911622762680054, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 307, Loss: 1.750673532485962, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 308, Loss: 1.183754324913025, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 309, Loss: 1.6042011976242065, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 310, Loss: 1.8559503555297852, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 311, Loss: 1.084964394569397, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 312, Loss: 1.4554439783096313, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 313, Loss: 1.3553813695907593, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 314, Loss: 1.6026873588562012, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 315, Loss: 1.4219266176223755, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 316, Loss: 1.5228407382965088, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 317, Loss: 1.104903221130371, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 318, Loss: 1.7881078720092773, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 319, Loss: 1.556204080581665, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 320, Loss: 1.2530277967453003, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 321, Loss: 1.6683586835861206, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 322, Loss: 1.4819668531417847, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 323, Loss: 1.7361385822296143, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 324, Loss: 1.1920937299728394, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 325, Loss: 1.7686808109283447, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 326, Loss: 1.3999639749526978, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 327, Loss: 1.512960433959961, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 328, Loss: 1.3476314544677734, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 329, Loss: 1.5618629455566406, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 330, Loss: 1.6110076904296875, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 331, Loss: 1.462628960609436, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 332, Loss: 1.5011745691299438, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 333, Loss: 1.3362841606140137, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 334, Loss: 1.1720530986785889, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 335, Loss: 1.5316420793533325, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 336, Loss: 1.2240625619888306, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 337, Loss: 1.128890872001648, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 338, Loss: 1.7756614685058594, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 339, Loss: 1.2482353448867798, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 340, Loss: 1.162599802017212, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 341, Loss: 1.3445980548858643, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 342, Loss: 1.4491444826126099, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 343, Loss: 1.4484390020370483, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 344, Loss: 1.2422045469284058, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 345, Loss: 1.625023603439331, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 346, Loss: 1.5555140972137451, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 347, Loss: 1.5754185914993286, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 348, Loss: 1.5596177577972412, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 349, Loss: 1.224680781364441, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 350, Loss: 1.2507719993591309, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 351, Loss: 1.5410760641098022, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 352, Loss: 1.4286656379699707, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 353, Loss: 1.348376750946045, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 354, Loss: 1.7348089218139648, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 355, Loss: 1.7221275568008423, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 356, Loss: 1.213818907737732, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 357, Loss: 1.5221816301345825, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 358, Loss: 1.2153035402297974, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 359, Loss: 1.0438158512115479, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 360, Loss: 1.2914365530014038, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 361, Loss: 1.743590235710144, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 362, Loss: 1.5266478061676025, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 363, Loss: 1.0900918245315552, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 364, Loss: 1.2366859912872314, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 365, Loss: 1.5564868450164795, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 366, Loss: 1.0534439086914062, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 367, Loss: 1.5635666847229004, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 368, Loss: 1.208978295326233, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 369, Loss: 1.2951723337173462, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 370, Loss: 1.2426525354385376, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 371, Loss: 1.3897466659545898, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 372, Loss: 1.4141899347305298, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 373, Loss: 1.369344711303711, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 374, Loss: 1.339927077293396, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 375, Loss: 1.5106449127197266, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 376, Loss: 1.9365818500518799, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 377, Loss: 1.210525393486023, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 378, Loss: 1.2648601531982422, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 379, Loss: 1.5063564777374268, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 1, Batch 380, Loss: 1.5253286361694336, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# ...
# Epoch 5, Batch 650, Loss: 0.616615891456604, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 651, Loss: 0.8404372334480286, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 652, Loss: 0.9901174902915955, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 653, Loss: 0.88721764087677, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 654, Loss: 0.7839489579200745, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 655, Loss: 0.7873947620391846, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 656, Loss: 0.795925498008728, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 657, Loss: 1.013527512550354, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 658, Loss: 0.8549197316169739, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 659, Loss: 0.8418511152267456, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 660, Loss: 0.7846959233283997, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 661, Loss: 0.9785311222076416, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 662, Loss: 0.6583240628242493, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 663, Loss: 0.7333944439888, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 664, Loss: 0.7291846871376038, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 665, Loss: 0.7154529690742493, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 666, Loss: 0.8484466075897217, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 667, Loss: 0.6532158851623535, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 668, Loss: 1.2001374959945679, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 669, Loss: 0.7849492430686951, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 670, Loss: 0.8329706192016602, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 671, Loss: 0.9208627343177795, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 672, Loss: 0.7861707210540771, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 673, Loss: 0.7705265879631042, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 674, Loss: 0.8046842813491821, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 675, Loss: 0.9769036173820496, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 676, Loss: 1.0450236797332764, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 677, Loss: 1.023676872253418, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 678, Loss: 0.7701762914657593, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 679, Loss: 0.7907304763793945, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 680, Loss: 1.5026390552520752, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 681, Loss: 0.7581576704978943, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 682, Loss: 0.7204177379608154, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 683, Loss: 1.0450823307037354, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 684, Loss: 0.9155291318893433, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 685, Loss: 1.0247111320495605, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 686, Loss: 0.7432295083999634, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 687, Loss: 1.0734971761703491, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 688, Loss: 0.9061578512191772, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 689, Loss: 1.0326155424118042, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 690, Loss: 0.9504746794700623, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 691, Loss: 0.8872449398040771, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 692, Loss: 0.831288754940033, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 693, Loss: 0.9135766625404358, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 694, Loss: 0.8480445742607117, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 695, Loss: 0.6709913611412048, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 696, Loss: 0.8042329549789429, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 697, Loss: 0.8500638008117676, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 698, Loss: 0.6415195465087891, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 699, Loss: 0.8537113070487976, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 700, Loss: 0.8816173076629639, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 701, Loss: 0.7010565996170044, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 702, Loss: 0.9006887078285217, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 703, Loss: 0.8294981122016907, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 704, Loss: 0.8802452683448792, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 705, Loss: 0.8784618377685547, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 706, Loss: 1.1983966827392578, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 707, Loss: 0.6917192935943604, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 708, Loss: 0.705638587474823, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 709, Loss: 0.8550820350646973, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 710, Loss: 0.9843844175338745, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 711, Loss: 1.0049830675125122, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 712, Loss: 0.858113169670105, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 713, Loss: 0.8044323921203613, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 714, Loss: 0.9489797949790955, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 715, Loss: 0.9480250477790833, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 716, Loss: 0.6395926475524902, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 717, Loss: 0.7385048866271973, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 718, Loss: 0.9972848892211914, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 719, Loss: 1.1607050895690918, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 720, Loss: 0.8731402158737183, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 721, Loss: 0.8879373669624329, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 722, Loss: 0.7862247228622437, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 723, Loss: 0.8651806116104126, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 724, Loss: 0.7745513319969177, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 725, Loss: 0.8696542382240295, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 726, Loss: 0.9513275623321533, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 727, Loss: 0.8977174162864685, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 728, Loss: 0.8953148722648621, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 729, Loss: 0.6775934100151062, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 730, Loss: 0.8361337780952454, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 731, Loss: 0.7639346718788147, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 732, Loss: 0.7797055244445801, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 733, Loss: 0.8792955875396729, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 734, Loss: 0.8666803240776062, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 735, Loss: 0.8972231149673462, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 736, Loss: 0.8900835514068604, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 737, Loss: 1.030739426612854, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 738, Loss: 1.0758775472640991, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 739, Loss: 0.8459774851799011, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 740, Loss: 1.1011580228805542, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 741, Loss: 0.8041331768035889, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 742, Loss: 0.7414366006851196, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 743, Loss: 0.9201425313949585, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 744, Loss: 0.7964532375335693, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 745, Loss: 0.9336521029472351, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 746, Loss: 0.7676767706871033, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 747, Loss: 0.7231238484382629, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 748, Loss: 0.8864774703979492, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 749, Loss: 1.0262097120285034, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 750, Loss: 0.7887728810310364, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 751, Loss: 0.8445528745651245, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 752, Loss: 0.7247440814971924, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 753, Loss: 0.9263556003570557, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 754, Loss: 0.901239812374115, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 755, Loss: 0.6995412111282349, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 756, Loss: 0.835538387298584, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 757, Loss: 0.8410335779190063, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 758, Loss: 0.9412938356399536, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 759, Loss: 0.8073242902755737, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 760, Loss: 0.9587863683700562, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 761, Loss: 0.9339367747306824, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 762, Loss: 0.6953059434890747, Inputs shape: torch.Size([8, 100]), Bert Embeddings shape: torch.Size([8, 768])
# Epoch 5, Batch 763, Loss: 1.1319217681884766, Inputs shape: torch.Size([2, 100]), Bert Embeddings shape: torch.Size([2, 768])
# Epoch 5 completed. Average Loss: 0.8998489715403061
# C:\Users\aamir\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# C:\Users\aamir\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Generated Response: What is the best hotel in Islamabad? and its address is address not available in Islamabad, costing Rs12648 per night. Small description: Check-out time: 12:00. Available facilities: Terrace, Spa, Restaurant.
# 'What is the best hotel in Islamabad? and its address is address not available in Islamabad, costing Rs12648 per night. Small description: Check-out time: 12:00. Available facilities: Terrace, Spa, Restaurant.'

# %%
import numpy as np
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel, AdamW
from sklearn.metrics.pairwise import cosine_similarity

# Load fine-tuned model and tokenizer
gpt_tokenizer = GPT2Tokenizer.from_pretrained('fine_tuned_gpt2')
gpt_model = GPT2LMHeadModel.from_pretrained('fine_tuned_gpt2')
gpt_model.eval()  # Set model to evaluation mode

# Set the pad_token_id to match the EOS token to handle padding correctly
gpt_tokenizer.pad_token = gpt_tokenizer.eos_token  # Set padding token to EOS token
gpt_model.config.pad_token_id = gpt_tokenizer.eos_token_id  # Set pad token ID to eos_token_id

# Load embeddings from the specified files
hotel_embedding_matrix = np.load('hotel_embeddings.npy')  # Load hotel embeddings
restaurant_embedding_matrix = np.load('restaurant_embeddings.npy')  # Load restaurant embeddings
attraction_embedding_matrix = np.load('attraction_embeddings.npy')  # Load attraction embeddings


# Generate response based on the prompt and add top suggestions if requested
def generate_response_gpt(prompt):
    # Encode the prompt and set up attention mask
    inputs = gpt_tokenizer.encode(prompt, return_tensors='pt', padding=True, truncation=True, max_length=100)
    attention_mask = (inputs != gpt_tokenizer.pad_token_id).long()

    with torch.no_grad():
        # Generate response with attention mask and pad token ID
        outputs = gpt_model.generate(
            inputs,
            max_length=100,
            num_return_sequences=1,
            temperature=0.7,
            top_p=0.9,
            attention_mask=attention_mask,
            pad_token_id=gpt_tokenizer.eos_token_id
        )

    response = gpt_tokenizer.decode(outputs[0], skip_special_tokens=True)

    return response

# User interaction loop
def chatbot():
    print("Welcome to the STELS Chatbot! Type 'exit' to end the chat.")
    while True:
        user_input = input("You: ")
        
        # Exit condition
        if user_input.lower() == "exit":
            print("Chatbot: Thank you for chatting. Goodbye!")
            break
        
        # Generate and print response
        response = generate_response_gpt(user_input)
        print(f"Chatbot: {response}")

# Run chatbot interaction
chatbot()
# Out:
# Welcome to the STELS Chatbot! Type 'exit' to end the chat.
# You:  suggest top 5 hotel according to rating inLahore
# Chatbot: suggest top 5 hotel according to rating inLahore and its address is address not available in Lahore, costing Rs12648 per night. Small description: Check-out time: 12:00. Available facilities: Terrace, Spa, Restaurant.
# You:  suggest  attraction spot in Islmabad
# Chatbot: suggest  attraction spot in Islmabad   located at WJ2X+QG9, Naran, Mansehra, Khyber Pakhtunkhwa and its phone number is 0300 8480022 in Naran. The provided services are not available and opening hour is not available.
# You:  exit
# Chatbot: Thank you for chatting. Goodbye!
